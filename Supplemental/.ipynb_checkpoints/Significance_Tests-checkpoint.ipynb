# %%
import pandas as pd
from scipy.stats import chi2_contingency

df = pd.read_csv('participation_ratios.csv', index_col=1)
df.drop(columns=['Unnamed: 0'], inplace=True)

df.head()
# Out:
#                   Total  Native American Number  Native American Percent  \
# State
# United States  50452567                  524730                   1.0400
# Alabama          745128                    8421                   1.1301
# Alaska           131895                   30910                  23.4353
# Arizona         1132436                   53711                   4.7430
# Arkansas         484562                    3160                   0.6521
#
#                Asian Number  Asian Percent  Hispanic Number  Hispanic Percent  \
# State
# United States       2498587         4.9523         13028012           25.8223
# Alabama               10704         1.4365            50219            6.7396
# Alaska                 7827         5.9343             8802            6.6735
# Arizona               32021         2.8276           504224           44.5256
# Arkansas               7662         1.5812            59618           12.3035
#
# ...

# %%
checks = []
ratios = ['Native American Participation Ratio',
               'Pacific Islander Participation Ratio',
               'Multiracial Participation Ratio']
for ratio in ratios:
    states = list(df[df[ratio]>1]['State'])
    states = [(state, ratio) for state in states]
    checks += states

checks
# Out:
# [('Delaware', 'Native American Participation Ratio'),
#  ('Florida', 'Native American Participation Ratio'),
#  ('Hawaii', 'Native American Participation Ratio'),
#  ('Louisiana', 'Native American Participation Ratio'),
#  ('West Virginia', 'Native American Participation Ratio'),
#  ('Colorado', 'Pacific Islander Participation Ratio'),
#  ('District of Columbia', 'Pacific Islander Participation Ratio'),
#  ('Kentucky', 'Pacific Islander Participation Ratio'),
#  ('Maine', 'Pacific Islander Participation Ratio'),
#  ('Massachusetts', 'Pacific Islander Participation Ratio'),
#  ('New Jersey', 'Pacific Islander Participation Ratio'),
#  ('South Carolina', 'Pacific Islander Participation Ratio'),
#  ('Tennessee', 'Pacific Islander Participation Ratio'),
#  ('Virginia', 'Pacific Islander Participation Ratio'),
#  ('Colorado', 'Multiracial Participation Ratio'),
#  ('District of Columbia', 'Multiracial Participation Ratio'),
#  ('Nevada', 'Multiracial Participation Ratio'),
# ...

# %%
for check in checks:
    group = check[1].replace(' Participation Ratio', '')
    a = df.loc[check[0], (group + ' Number')]
    b = df.loc[check[0], (group + ' Number AP')]
    c = df.loc[check[0], 'Total']
    d = df.loc[check[0], 'Total AP']
    chi2 = chi2_contingency([[a,b],[c,d]])
    if chi2[1] < 0.1:
        print(f'Significant result {check} with p-value {chi2[1]}')
        print(
            f'There are {a} {group} students enrolled ({(a/c*100):.2f}% of all students), '
            f'and there are {b} {group} test takers ({b/d*100:.2f}%).\n'
        )
# Out:
# Significant result ('South Carolina', 'Pacific Islander Participation Ratio') with p-value 0.08615237442704812
# There are 1049 Pacific Islander students enrolled (0.14% of all students), and there are 49 Pacific Islander test takers (0.18%).
#
# Significant result ('District of Columbia', 'Multiracial Participation Ratio') with p-value 0.00679118924993587
# There are 1578 Multiracial students enrolled (1.92% of all students), and there are 96 Multiracial test takers (2.57%).
